# %% [markdown]
# <a href="https://colab.research.google.com/github/JimenezHAnaFer/SIMULACION-1/blob/main/Distribuci%C3%B3n_Triangular.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Avance 1***

# %%
import numpy as np
import matplotlib.pyplot as plt
import random as rd

#Ponemos nuestros parametros
a = 2   # mínimo
b = 10  # máximo
c = 6   # moda

# %%
import numpy as np
import matplotlib.pyplot as plt
import random as rd

# Parámetros de la distribución triangular
a = 2   # mínimo
b = 6  # moda
c = 10   # maximo
n=1000  #cantidad de numeros aleatorios
# Función para generar valores con distribución triangular
def distribucion_triangular(a, b, c, n):
    resultados = []
    for _ in range(n):
        r = rd.random() # genera un valor entre 0 y 1
        if r < (b-a)/(c-a):  # Zona izquierda (a ≤ x ≤ c): línea creciente    &    Zona derecha (c < x ≤ b): línea decreciente
            x = a + np.sqrt(r*(c-a)*(b-a))   #Función acomulativa
        else:
            x = c - np.sqrt((1-r)*(c-a)*(c-b))  #Función acumulativa
        resultados.append(x)
    return np.array(resultados)

#print(distribucion_triangular(a, b, c, n))
plt.hist(distribucion_triangular(a, b, c, n), bins=50, density=True, color='skyblue', edgecolor='black', alpha=0.7)
# Out:
# (array([0.02577481, 0.02577481, 0.02577481, 0.01933111, 0.03221852,
#         0.05799333, 0.05799333, 0.12243037, 0.07732444, 0.08376815,
#         0.07088074, 0.09021185, 0.10309926, 0.06443704, 0.17398   ,
#         0.14820519, 0.18686741, 0.17398   , 0.19331111, 0.1804237 ,
#         0.22552963, 0.19975481, 0.28352296, 0.23841704, 0.25774815,
#         0.26419185, 0.1804237 , 0.18686741, 0.19975481, 0.28996667,
#         0.1804237 , 0.21264222, 0.18686741, 0.12243037, 0.19331111,
#         0.12243037, 0.12887407, 0.1675363 , 0.14820519, 0.09665556,
#         0.08376815, 0.06443704, 0.10309926, 0.07732444, 0.10954296,
#         0.03221852, 0.05799333, 0.03866222, 0.04510593, 0.03221852]),
#  array([2.01650466, 2.17169491, 2.32688517, 2.48207542, 2.63726567,
#         2.79245592, 2.94764617, 3.10283643, 3.25802668, 3.41321693,
#         3.56840718, 3.72359743, 3.87878769, 4.03397794, 4.18916819,
#         4.34435844, 4.49954869, 4.65473894, 4.8099292 , 4.96511945,
#         5.1203097 , 5.27549995, 5.4306902 , 5.58588046, 5.74107071,
#         5.89626096, 6.05145121, 6.20664146, 6.36183171, 6.51702197,
#         6.67221222, 6.82740247, 6.98259272, 7.13778297, 7.29297323,
#         7.44816348, 7.60335373, 7.75854398, 7.91373423, 8.06892448,
#         8.22411474, 8.37930499, 8.53449524, 8.68968549, 8.84487574,
#         9.000066  , 9.15525625, 9.3104465 , 9.46563675, 9.620827  ,
#         9.77601726]),
#  <BarContainer object of 50 artists>)

# %%
import numpy as np
import matplotlib.pyplot as plt
import random as rd

# Parámetros de la distribución triangular
a = 2   # mínimo
b = 6  # moda
c = 10   # maximo
n=1000  #cantidad de numeros aleatorios
# Función para generar valores con distribución triangular
def distribucion_triangular(a, b, c, n):
    resultados = []
    for _ in range(n):
        r = rd.random() # genera un valor entre 0 y 1
        if r < (b-a)/(c-a):  # Zona izquierda (a ≤ x ≤ c): línea creciente    &    Zona derecha (c < x ≤ b): línea decreciente
            x = a + np.sqrt(r*(c-a)*(b-a))   #Función acomulativa
        else:
            x = c - np.sqrt((1-r)*(c-a)*(c-b))  #Función acumulativa
        resultados.append(x)
    return np.array(resultados)

#print(distribucion_triangular(a, b, c, n))

# Generar muestra
muestra = distribucion_triangular(a, b, c, 10000)

print(np.var(muestra))
print(np.mean(muestra))
# Out:
# 2.627969442095001
# 6.003548017317592

# %% [markdown]
# *Codigo completo*

# %% [markdown]
# # Distribución Triangular

# %% [markdown]
# Una distribución triangular es una distribución continua que se describe por sus valores mínimos, máximos y su moda. La distribución tiene una forma triangular. Comienza en el valor mínimo, aumenta de manera lineal hasta alcanzar el valor pico en la moda y luego disminuye de manera lineal hasta alcanzar el valor máximo. La forma del triángulo puede ser simétrica o asimétrica.

# %% [markdown]
# **Función de densidad de probabilidad**

# %% [markdown]
# f(x) = \begin{cases}
#     \frac{2(x-a)}{(b-a)(c-a)} & \text{si } a \le x \le b \\
#     \frac{2(c-x)}{(c-a)(c-b)} & \text{si } b < x \le c
# \end{cases}

# %% [markdown]
# **Función acumulativa**

# %% [markdown]
# F(x) = \begin{cases}
#     \frac{(x-a)^2}{(c-a)(b-a)} & \text{si } a \le x \le b \\
#     1 + \frac{(c-x)^2}{(c-a)(c-b)} & \text{si } b < x \le c
# \end{cases}

# %%
import numpy as np
import matplotlib.pyplot as plt
import random as rd

# Parámetros de la distribución triangular
a = 1   # mínimo
b = 3  # moda
c = 5   # maximo
n=500000  #cantidad de numeros aleatorios

resultados = []
# Función para generar valores con distribución triangular
def distribucion_triangular(a, b, c, n):

    for _ in range(n):
        r = rd.random() # genera un valor entre 0 y 1
        if r < (b-a)/(c-a):  # Zona izquierda (a ≤ x ≤ b): línea creciente    &    Zona derecha (b < x ≤ c): línea decreciente
            x = a + np.sqrt(r*(c-a)*(b-a))   #Función acomulativa (inversa)
        else:
            x = c - np.sqrt((1-r)*(c-a)*(c-b))  #Función acumulativa (inversa)
        resultados.append(x)
    return np.array(resultados)



# Generar muestra
muestra = distribucion_triangular(a, b, c, n)



print('La varianza es:', np.var(muestra))
print('La media es:', np.mean(muestra))


plt.hist(muestra, bins=50, density=True, color='skyblue', edgecolor='black', alpha=0.7)
plt.title('Histograma de la Distribución Triagular')
plt.xlabel('Valores')
plt.ylabel('Densidad')
plt.grid(True)
plt.show()


# Calcular la distribución acumulativa
acumulativa = np.sort(muestra)
for i in range(len(acumulativa)):
    acumulativa[i] = (i + 1) / len(acumulativa)  #Recuerda que se le suma 1 al numerador

# Graficar la distribución acumulativa
plt.plot(np.sort(muestra), acumulativa, linestyle='-', color='blue')
plt.title('Distribución Acumulativa de la Distribución Triangular')
plt.xlabel('Valores')
plt.ylabel('Probabilidad Acumulativa')
plt.grid(True)
plt.show()
# Out:
# La varianza es: 0.6665789106924206
# La media es: 3.0005580032698487
