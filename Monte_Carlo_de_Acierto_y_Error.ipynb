# %% [markdown]
# <a href="https://colab.research.google.com/github/JimenezHAnaFer/SIMULACION-1/blob/main/Monte_Carlo_de_Acierto_y_Error.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *Avance 1*

# %%
import random as rd
import numpy as np
import matplotlib.pyplot as plt

# Definimos nuestra función
def f(x):
    return np.sqrt(np.arctan(x))

x = np.linspace(0, 1, 10)
y = f(x)

print(x)
print(y)
# Out:
# [0.         0.11111111 0.22222222 0.33333333 0.44444444 0.55555556
#  0.66666667 0.77777778 0.88888889 1.        ]
# [0.         0.3326518  0.46762051 0.5672306  0.64670266 0.71210849
#  0.76681328 0.81304561 0.85243319 0.88622693]

# %% [markdown]
# *Avance 2*

# %%
import random as rd
import numpy as np
import matplotlib.pyplot as plt

# Definimos nuestra función
def f(x):
    return np.sqrt(np.arctan(x))

x = np.linspace(0, 1, 10)
y = f(x)

print(x)
print(y)

#Definimos la función de Monte Carlo
def dardos(n):
    exitos = 0  # Contador
    for _ in range(n):
        u1 = rd.random()
        u2 = rd.random()
        if u2 <= f(u1):  # Si está debajo de la curva, es un éxito
            exitos += 1
    return exitos / n

dardos(1000)
# Out:
# [0.         0.11111111 0.22222222 0.33333333 0.44444444 0.55555556
#  0.66666667 0.77777778 0.88888889 1.        ]
# [0.         0.3326518  0.46762051 0.5672306  0.64670266 0.71210849
#  0.76681328 0.81304561 0.85243319 0.88622693]
# 0.66

# %% [markdown]
# *Avance 3*

# %%
import random as rd
import numpy as np
import matplotlib.pyplot as plt

# Definimos nuestra función
def f(x):
    return np.sqrt(np.arctan(x))

x = np.linspace(0, 1, 10)
y = f(x)

print(x)
print(y)

#Definimos la función de Monte Carlo
def dardos(n):
    exitos = 0  # Contador
    for _ in range(n):
        u1 = rd.random()
        u2 = rd.random()
        if u2 <= f(u1):  # Si está debajo de la curva, es un éxito
            exitos += 1
    return exitos / n

dardos(1000)
# Calcular probabilidad
probabilidad = dardos(1000000)
print('La probabilidad es:',probabilidad)
# Out:
# [0.         0.11111111 0.22222222 0.33333333 0.44444444 0.55555556
#  0.66666667 0.77777778 0.88888889 1.        ]
# [0.         0.3326518  0.46762051 0.5672306  0.64670266 0.71210849
#  0.76681328 0.81304561 0.85243319 0.88622693]
# La probabilidad es: 0.630271

# %% [markdown]
# *Avance 4 (graficas)*

# %%
import random as rd
import numpy as np
import matplotlib.pyplot as plt

# Definimos nuestra función
def f(x):
    return np.sqrt(np.arctan(x))

x = np.linspace(0, 1, 10000)
y = f(x)

#print(x)
#print(y)

#Definimos la función de Monte Carlo
def dardos(n):
    exitos = 0  # Contador
    for _ in range(n):
        u1 = rd.random()
        u2 = rd.random()
        if u2 <= f(u1):  # Si está debajo de la curva, es un éxito
            exitos += 1
    return exitos / n

dardos(1000)
# Calcular probabilidad
probabilidad = dardos(1000000)
print('La probabilidad es:',probabilidad)

# Graficamos la función
plt.plot(x, y)
plt.axhline(f(1), color="red")
plt.axvline(1, color="red", linestyle="--")
plt.scatter(u1, u2, color = "green")
plt.show()
# Out:
# La probabilidad es: 0.630452

# %% [markdown]
# *Avance 5 (función de experimentos)*

# %%
import random as rd
import numpy as np
import matplotlib.pyplot as plt

# Definimos nuestra función
def f(x):
    return np.sqrt(np.arctan(x))

x = np.linspace(0, 1, 10000)
y = f(x)

#print(x)
#print(y)

#Definimos la función de Monte Carlo
def dardos(n):
    exitos = 0  # Contador
    for _ in range(n):
        u1 = rd.random()
        u2 = rd.random()
        if u2 <= f(u1):  # Si está debajo de la curva, es un éxito
            exitos += 1
    return exitos / n

dardos(1000)
# Calcular probabilidad
probabilidad = dardos(1000000)
print('La probabilidad es:',probabilidad)

# Graficar la función
plt.plot(x, y)
plt.axhline(f(1), color="red")
plt.axvline(1, color="red", linestyle="--")
plt.scatter(u1, u2, color="green")
plt.show()

# Función para realizar múltiples experimentos
def experimento(m, n=100000):
    lista = [dardos(n) for _ in range(m)]
    return lista

# Ejecutar el experimento 300 veces
l = experimento(300)
print("Última estimación:", l[-1])
# Out:
# La probabilidad es: 0.630858
# Última estimación: 0.62984

# %% [markdown]
# *Codigo completo (con graficas)*

# %%
import random as rd
import numpy as np
import matplotlib.pyplot as plt

# Definimos nuestra función
def f(x):
    return np.sqrt(np.arctan(x))

x = np.linspace(0, 1, 10000)
y = f(x)

#print(x)
#print(y)

#Definimos la función de Monte Carlo
def dardos(n):
    exitos = 0  # Contador
    for _ in range(n):
        u1 = rd.random()
        u2 = rd.random()
        if u2 <= f(u1):  # Si está debajo de la curva, es un éxito
            exitos += 1
    return exitos / n

dardos(1000)
# Calcular probabilidad
probabilidad = dardos(1000000)
print('La probabilidad es:',probabilidad)

# Graficar la función
plt.plot(x, y)
plt.axhline(f(1), color="red")
plt.axvline(1, color="red", linestyle="--")

# Graficar puntos aleatorios de prueba
u1 = rd.random()
u2 = rd.random()
plt.scatter(u1, u2, color="green", label="Ejemplo de punto aleatorio")



plt.scatter(u1, u2, color = "green")
plt.show()


# Función para realizar múltiples experimentos
def experimento(m, n=10000):
    lista = [dardos(n) for _ in range(m)]
    return lista

# Ejecutar el experimento 300 veces
l = experimento(300)
print("Última estimación:", l[-1])

# Graficar la evolución de las estimaciones
plt.plot(l)
plt.axhline(np.mean(l), color="red", linestyle="--")
plt.legend()
plt.show()

# Resultados
print("Media de las estimaciones:", np.mean(l))
print("Varianza de las estimaciones:", np.var(l))
# Out:
# La probabilidad es: 0.630843
# Última estimación: 0.6291
# <ipython-input-6-47ba4e0c7810>:58: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Media de las estimaciones: 0.6296480000000001
# Varianza de las estimaciones: 2.3147895999999988e-05
